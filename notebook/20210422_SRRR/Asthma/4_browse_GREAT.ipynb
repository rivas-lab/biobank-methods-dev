# %%
suppressWarnings(suppressPackageStartupMessages({
    library(tidyverse)
    library(data.table)
}))

# %%
source('parameters.sh')

# %%
file.path(ref_d, 'ontology', paste0(ontology, '.', onto_terms))  %>%
fread(col.names=c('term_ID', 'term_desc', 'onto_P', 'onto_lvl')) %>% 
select(term_ID, term_desc) -> ontoTerms_df

# %%
file.path(data_d, results_sub_d, rdata_base, 'GREAT_out', paste0(ontology, '.tsv.gz')) %>%
fread() %>%
rename('sample_ID'='#sample_ID') %>%
group_by(sample_ID) %>%
mutate(BRank = 1:n()) %>%
ungroup() -> great_res_df

# %%
great_res_df %>% filter(BRank <= 5) %>%
left_join(ontoTerms_df, by = "term_ID")
# Out:
#    sample_ID  ontology         term_ID    BPval        BFold    Bn   Bk
# 1  Component1 MGIPhenoSingleKO MP:0001800 7.797674e-41 2.010051 5000 430
# 2  Component1 MGIPhenoSingleKO MP:0000691 1.136927e-40 2.158741 5000 364
# 3  Component1 MGIPhenoSingleKO MP:0020201 2.158901e-40 2.056720 5000 403
# 4  Component1 MGIPhenoSingleKO MP:0002441 4.635878e-40 2.013868 5000 420
# 5  Component1 MGIPhenoSingleKO MP:0002401 1.384330e-39 1.936437 5000 457
# 6  Component2 MGIPhenoSingleKO MP:0002458 8.946989e-25 1.681605 5000 429
# 7  Component2 MGIPhenoSingleKO MP:0008171 1.660215e-24 1.675970 5000 429
# 8  Component2 MGIPhenoSingleKO MP:0000691 1.085833e-22 1.820696 5000 307
# 9  Component2 MGIPhenoSingleKO MP:0005017 4.153783e-22 1.745323 5000 339
# 10 Component2 MGIPhenoSingleKO MP:0002401 7.542655e-21 1.644064 5000 388
# 11 Component3 MGIPhenoSingleKO MP:0002401 2.056011e-64 2.241521 5000 529
# 12 Component3 MGIPhenoSingleKO MP:0001800 6.513130e-60 2.262476 5000 484
# ...
